# %% [markdown]
# ## First, install uv. It's a Python package manager, and I switched all my projects to it because it's fast and convenient. Once I started using it, I never wanted to go back.
#
# ## On Mac or Linux:

# %%
curl -LsSf https://astral.sh/uv/install.sh | sh

# %% [markdown]
# ## Create an empty folder for the project and initialize it:

# %%
uv init

# %% [markdown]
# ## Now add the dependencies we'll need:

# %%
uv add requests minsearch openai jupyter python-dotenv

# %% [markdown]
# ## Create a .env file in your project folder and put your API key in it:

# %%
OPENAI_API_KEY=sk-YOUR_KEY_HERE

# %% [markdown]
# ## Now add .env to .gitignore to make sure you never accidentally commit your key:

# %%
.env

# %% [markdown]
# ## Check that the OpenAI client works:

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
def llm(prompt):
    response = openai_client.responses.create(
        model='gpt-5.4-nano',
        input=prompt
    )
    return response.output_text

# %%
question = 'I just discovered the course. Can I join now?'
answer = llm(question)
print(answer)
# Out:
# It depends on the course’s enrollment rules. Many courses allow late enrollment, but some have a closing date or require you to start at a specific week.
#
# If you share the course name/link (or the platform it’s on), I can tell you exactly where to check and what the usual deadlines are.

# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key=os.environ.get("ANTHROPIC_API_KEY"),  # Your Claude API key
    base_url="https://api.anthropic.com/v1/",     # Claude's endpoint
)

response = client.chat.completions.create(
    model="claude-opus-4-8",                      # Claude model name
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Who are you?"},
    ],
)

print(response.choices[0].message.content)
# Out:
# I'm Claude, an AI assistant made by Anthropic. I'm designed to be helpful, harmless, and honest in my interactions. I can assist with a wide range of tasks like answering questions, writing, analysis, brainstorming, problem-solving, and general conversation.
#
# Is there something I can help you with today?
